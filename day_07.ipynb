# %% [markdown]
# <a href="https://colab.research.google.com/github/Alliance2k2/Alliance2k2/blob/main/day_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Function

# %%
def multiplication_table_8():
  n = 1
  while n <= 20:
    v = n*8
    print(n,'x',8,'=',v,sep='')
    n = n + 1
multiplication_table_8()
# Out:
# 1x8=8
# 2x8=16
# 3x8=24
# 4x8=32
# 5x8=40
# 6x8=48
# 7x8=56
# 8x8=64
# 9x8=72
# 10x8=80
# 11x8=88
# 12x8=96
# 13x8=104
# 14x8=112
# 15x8=120
# 16x8=128
# 17x8=136
# 18x8=144
# 19x8=152
# 20x8=160

# %%
def square(x):
  """""
  This function calculates the square of a given number.
  input: The number x to be squared
  output: The square of the input number
  """
  return x**2

# %%
square(4)
# Out:
# 16

# %%
def area_rectangle(l,w):
  """
  This function calculates the Area of rectangle.
  input:the number of length(l) and the number of width(w)
  output:area of lectangle

  """
  area = l * w
  print("The area of a rectangle is:",area)

# %%
area_rectangle(2,4)
# Out:
# The area of a rectangle is: 8

# %%
def table(base, start, end):
    """Displays the multiplication table of <base> from <start> to <end>."""
    n = start
    while n <= end:
        print(n, 'x', base, '=', n * base, end=" ")
        n += 1
table(7, 2, 11)
# Out:
# 2 x 7 = 14 3 x 7 = 21 4 x 7 = 28 5 x 7 = 35 6 x 7 = 42 7 x 7 = 49 8 x 7 = 56 9 x 7 = 63 10 x 7 = 70 11 x 7 = 77

# %%
def multiplication_table(n):
    """
    The purpose of this function is to display the multiplication table for a given number `n`.
    Input: n (int) - The number for which the multiplication table will be generated.
    Output: The multiplication table for `n`.
    """
    print(f"Multiplication Table for {n}:")
    print("=" * 25)
    for i in range(1, 21):
        result = i * n
        print(f"{i:2} x {n:2} = {result:3}")
    print("=" * 25)

# Example usage:
multiplication_table(8)
# Out:
# Multiplication Table for 8:
# ...
#  1 x  8 =   8
#  2 x  8 =  16
#  3 x  8 =  24
#  4 x  8 =  32
#  5 x  8 =  40
#  6 x  8 =  48
#  7 x  8 =  56
#  8 x  8 =  64
#  9 x  8 =  72
# 10 x  8 =  80
# 11 x  8 =  88
# 12 x  8 =  96
# 13 x  8 = 104
# 14 x  8 = 112
# 15 x  8 = 120
# 16 x  8 = 128
# 17 x  8 = 136
# 18 x  8 = 144
# 19 x  8 = 152
# 20 x  8 = 160
# ...
